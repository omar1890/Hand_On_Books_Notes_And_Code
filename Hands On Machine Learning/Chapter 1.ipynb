# %% [markdown]
# <h3>What Is Machine Learning?</h3>
# <br>
# is the science (and art) of programming computers so they can
# learn from data

# %% [markdown]
# <h3>Machine Learning is great for:</h3>
# <p>
# <br>• Problems for which existing solutions require a lot of     fine-tuning or long lists of rules: one Machine Learning     algorithm can often simplify code and perform better than     the traditional approach.
# <br>• Complex problems for which using a traditional approach       yields no good solution: the best Machine Learning           techniques can perhaps find a solution.
# <br>• Fluctuating environments: a Machine Learning system can       adapt to new data.
# <br>• Getting insights about complex problems and large             amounts of data
# </p>

# %% [markdown]
# <h3>Examples of Applications</h3>
# <p>
# <br>- Analyzing images of products on a production line to automatically classify them - ch14
# <br> - Detecting tumors in brain scans (CNN)
# <br> - Automatically classifying news articles(NLP->text classification,RNN,CNN,Tranformers) -ch16
# <br> - Automatically flagging offensive comments on discussion forums (Text classification-NLP)
# <br> - Summarizing long documents automatically (NLP)
# <br> - Creating a chatbot or a personal assistant
# <br> - Forecasting your company’s revenue next year, based on many performance metrics (Regression task,if we take into account sequences of past performance metrics ->RNN,CNN)-
#     ch4,5,7,10,15,16
# <br> - Making your app react to voice commands (RNN,CNN,Transformars) - ch15,16
# <br> - Making your app react to voice commands
# <br> - Segmenting clients based on their purchases so that you can design a different marketing
# strategy for each segment-ch9
# <br> - Representing a complex, high-dimensional dataset in a clear and insightful diagram (dimensionality reduction techniques)- ch8
# <br> -Recommending a product that a client may be interested in, based on past purchases-  ch10
# <br> - Building an intelligent bot for a game - ch18
# </p>

# %% [markdown]
# <h3>Building an intelligent bot for a game </h3>
# <p>
# **  (supervised, unsupervised, semisupervised, and Reinforcement Learning)
# <br>
# **(online versus batch learning)
# <br>
# ** (instance-based versus model-based learning)
# </p>

# %% [markdown]
# # ==============================

# %% [markdown]
# # Types of ML <br> ------------------

# %% [markdown]
# ### supervised :
# the training set you feed to the algorithm includes the desired solutions, called labels
#
# ##### The most important supervised learning algorithms
# • k-Nearest Neighbors
# • Linear Regression
# • Logistic Regression
# • Support Vector Machines (SVMs)
# • Decision Trees and Random Forests
# • Neural networks

# %% [markdown]
# ### Unsupervised learning :
# you might guess, the training data is unlabeled
#
# #### The most important unsupervised learning algorithms
#
# • Clustering:
# <br>
#     — K-Means<br>
#     — DBSCAN<br>
#     — Hierarchical Cluster Analysis (HCA)<br>
# <br>
# • Anomaly detection and novelty detection<br>
#     — One-class SVM<br>
#     — Isolation Forest<br>
# <br>
# • Visualization and dimensionality reduction<br>
#     — Principal Component Analysis (PCA)<br>
#     — Kernel PCA<br>
#     — Locally Linear Embedding (LLE)<br><br>
#     — t-Distributed Stochastic Neighbor Embedding (t-SNE)<br>
# <br>
# • Association rule learning<br>
#     — Apriori<br>
#     — Eclat<br>

# %% [markdown]
# ### Semisupervised learning :
# Since labeling data is usually time-consuming and costly, you will often have plenty of unlabeled instances, and few labeled instances. Some algorithms can deal with data that’s partially labeled <br>
# ##### Most semisupervised learning algorithms are combinations of unsupervised and supervised algorithms.
# <br>
# For example, deep belief networks (DBNs) are based on unsu‐
# pervised components called restricted Boltzmann machines (RBMs) stacked on top of
# one another. RBMs are trained sequentially in an unsupervised manner

# %% [markdown]
# ### Reinforcement Learning:
# is a very different beast. The learning system, called an agent in this context, can observe the environment, select and perform actions, and get rewards in return

# %% [markdown]
# ### Batch learning
# In batch learning, the system is incapable of learning incrementally: it must be trained using all the available data.
# This will generally take a lot of time and computing
# resources, so it is typically done offline.

# %% [markdown]
# ### Online learning
# In online learning, you train the system incrementally by feeding it data instances
# sequentially, either individually or in small groups called mini-batches. Each learning
# step is fast and cheap,

# %% [markdown]
# ### Instance-based learning
# This is called instance-based learning: the system learns the examples by heart, then
# generalizes to new cases by using a similarity measure to compare them to the
# learned examples (or a subset of them).

# %% [markdown]
# ### Model-based learning:
# generalize from a set of examples is to build a model of these exam‐
# ples and then use that model to make predictions.

# %% [markdown]
# ### In summary:
# • You studied the data.<br>
# • You selected a model.<br>
# • You trained it on the training data (i.e., the learning algorithm searched for the model parameter values that minimize a cost function).<br>
# • Finally, you applied the model to make predictions on new cases (this is called inference), hoping that this model will generalize well.

# %% [markdown]
# # =============================

# %% [markdown]
# # Main Challenges of Machine Learning <br> -----------------------------------

# %% [markdown]
# ## *“bad data.” <br> ---------------------

# %% [markdown]
# ### Insufficient Quantity of Training Data:
# Even for very simple problems you typically need
# thousands of examples, and for complex problems such as image or speech recognition you may need millions of examples

# %% [markdown]
# ### Nonrepresentative Training Data
# By using a nonrepresentative training set, we trained a model that is unlikely to make accurate predictions,
#
# #### sampling noise  :
# if the sample is too small
#
# #### sampling bias:
# even very large samples can be nonrepresentative if the sampling method is flawed.

# %% [markdown]
# ### Poor-Quality Data
# Obviously, if your training data is full of errors, outliers, and noise (e.g., due to poorquality measurements)

# %% [markdown]
# ### Irrelevant Features (garbage in, garbage out.)
# #### feature engineering:
# involves the following steps:
# <br>• Feature selection (selecting the most useful features to train on among existing features)
# <br>• Feature extraction (combining existing features to produce a more useful one—as we saw earlier, dimensionality reduction algorithms can help)
# <br>• Creating new features by gathering new data

# %% [markdown]
# ## *“bad Algorithms.” <br> ---------------------

# %% [markdown]
# ### Overfitting the Training Data :
# Complex models such as deep neural networks can detect subtle patterns in the data,but if the training set is noisy, or if it is too small (which introduces sampling noise),then the model is likely to detect patterns in the noise itself. Obviously these patterns will not generalize to new instances
#
# #### Solutions :
# • Simplify the model by selecting one with fewer parameters
# (e.g., a linear model rather than a high-degree polynomial
# model), by reducing the number of attributes in the training
# data, or by constraining the model.
# <br>• Gather more training data.
# <br>• Reduce the noise in the training data (e.g., fix data errors and
# remove outliers).

# %% [markdown]
# ### Underfitting the Training Data
# underfitting is the opposite of overfitting: it occurs when your model is too simple to learn the underlying structure of the data
#
# #### Solutions :
# • Select a more powerful model, with more parameters.
# <br>• Feed better features to the learning algorithm (feature engineering).
# <br>• Reduce the constraints on the model (e.g., reduce the regularization hyperpara‐
# meter).

# %%
from IPython.display import Image
Image('stepping back.PNG')

# %% [markdown]
# ## Testing and Validating
# A better option is to split your data into two sets: the training set and the test set. As
# these names imply, you train your model using the training set, and you test it using
# the test set. The error rate on new cases is called the generalization error

# %% [markdown]
# ## Hyperparameter Tuning and Model Selection

# %% [markdown]
# ## Data Mismatch

# %%
from IPython.display import Image
Image('No Free Lunch Theorem.PNG')

# %% [markdown]
# #                     The End
